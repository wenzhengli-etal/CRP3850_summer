# %% [markdown]
# # Using Different Data Sets
#
# ### 311 Service Requests in NYC
# NYC311 can provide you access to non-emergency City services and information about City government programs. NYC311 can help with a broad range of services, including things like homeless person assistance, pothole repair, or help understanding a property tax bill.
#
# **The goal of this exercise is the count the number of noise complaints in New York City by neighborhood.**

# %%
# Analysis
import geopandas as gpd
import pandas as pd
from numpy.random import seed
import os
import numpy as np

## warnings is a module that allows you to filter warnings
import warnings
## we are going to ignore all warnings (so they won't print)
warnings.filterwarnings("ignore")

# %%
##For this exercise, we are using Application Programming Interfaces (APIs) to import information. APIs allow softwares to talk to each other. 
##That is why Python can bring in data from the NYC Open Data just with the link

nyc_311_url = "https://data.cityofnewyork.us/resource/erm2-nwe9.json"
nyc_311 = pd.read_json(nyc_311_url)

##show the first five rows of the dataframe
nyc_311.head()
# Out:
#    unique_key             created_date agency  \
# 0    61344586  2024-06-03T01:51:05.000    DHS
# 1    61343327  2024-06-03T01:50:51.000   NYPD
# 2    61349320  2024-06-03T01:50:31.000    DHS
# 3    61345528  2024-06-03T01:50:19.000   NYPD
# 4    61345639  2024-06-03T01:49:23.000   NYPD
#
#                        agency_name              complaint_type  \
# 0  Department of Homeless Services  Homeless Person Assistance
# 1  New York City Police Department     Noise - Street/Sidewalk
# 2  Department of Homeless Services  Homeless Person Assistance
# 3  New York City Police Department            Blocked Driveway
# 4  New York City Police Department          Noise - Commercial
#
#          descriptor        location_type  incident_zip  \
# 0           Chronic      Street/Sidewalk       10036.0
# 1  Loud Music/Party      Street/Sidewalk       10455.0
# 2           Chronic      Street/Sidewalk       10013.0
# 3    Partial Access      Street/Sidewalk       11368.0
# 4  Loud Music/Party  Club/Bar/Restaurant       11103.0
#
#          incident_address         street_name  ...  \
# 0            729 8 AVENUE            8 AVENUE  ...
# 1  455 SOUTHERN BOULEVARD  SOUTHERN BOULEVARD  ...
# 2        75 CENTRE STREET       CENTRE STREET  ...
# 3        35-01 109 STREET          109 STREET  ...
# 4   28-04 STEINWAY STREET     STEINWAY STREET  ...
#
#   :@computed_region_sbqj_enih :@computed_region_7mpf_4k6g vehicle_type  \
# 0                        10.0                        10.0          NaN
# 1                        23.0                        23.0          NaN
# 2                         2.0                         2.0          NaN
# 3                        73.0                        73.0          NaN
# 4                        72.0                        72.0          NaN
#
#   closed_date taxi_pick_up_location bridge_highway_name  \
# 0         NaN                   NaN                 NaN
# 1         NaN                   NaN                 NaN
# 2         NaN                   NaN                 NaN
# 3         NaN                   NaN                 NaN
# 4         NaN                   NaN                 NaN
#
#   bridge_highway_direction road_ramp bridge_highway_segment facility_type
# 0                      NaN       NaN                    NaN           NaN
# 1                      NaN       NaN                    NaN           NaN
# 2                      NaN       NaN                    NaN           NaN
# 3                      NaN       NaN                    NaN           NaN
# 4                      NaN       NaN                    NaN           NaN
#
# [5 rows x 45 columns]

# %%
##we are interested in looking at the different neighborhoods (i.e. Manhattan, Bronx, Queens... etc.). 
##Identify the column that has that information and show the first five rows of that specific column

nyc_311.columns
nyc_311['park_borough'].head()
# Out:
# 0    MANHATTAN
# 1        BRONX
# 2    MANHATTAN
# 3       QUEENS
# 4       QUEENS
# Name: park_borough, dtype: object

# %%
## Now that we have identified the neighborhoods, can we find the complaint types and make a separate dataframe with only noise-complaints?

noise_311 = nyc_311.loc[nyc_311['complaint_type'].apply(lambda x: 'Noise -' in x),:]
noise_311.head()
# Out:
#     unique_key             created_date agency  \
# 1     61343327  2024-06-03T01:50:51.000   NYPD
# 4     61345639  2024-06-03T01:49:23.000   NYPD
# 7     61347978  2024-06-03T01:48:06.000   NYPD
# 12    61345658  2024-06-03T01:44:04.000   NYPD
# 13    61347981  2024-06-03T01:43:15.000   NYPD
#
#                         agency_name           complaint_type  \
# 1   New York City Police Department  Noise - Street/Sidewalk
# 4   New York City Police Department       Noise - Commercial
# 7   New York City Police Department  Noise - Street/Sidewalk
# 12  New York City Police Department      Noise - Residential
# 13  New York City Police Department  Noise - Street/Sidewalk
#
#           descriptor               location_type  incident_zip  \
# 1   Loud Music/Party             Street/Sidewalk       10455.0
# 4   Loud Music/Party         Club/Bar/Restaurant       11103.0
# 7   Loud Music/Party             Street/Sidewalk       11369.0
# 12  Loud Music/Party  Residential Building/House       10010.0
# 13      Loud Talking             Street/Sidewalk       10030.0
#
#           incident_address         street_name  ...  \
# 1   455 SOUTHERN BOULEVARD  SOUTHERN BOULEVARD  ...
# 4    28-04 STEINWAY STREET     STEINWAY STREET  ...
# 7         109-04 31 AVENUE           31 AVENUE  ...
# 12    202 EAST   21 STREET    EAST   21 STREET  ...
# 13           2400 7 AVENUE            7 AVENUE  ...
#
#    :@computed_region_sbqj_enih :@computed_region_7mpf_4k6g vehicle_type  \
# 1                         23.0                        23.0          NaN
# 4                         72.0                        72.0          NaN
# 7                         73.0                        73.0          NaN
# 12                         7.0                         7.0          NaN
# 13                        20.0                        20.0          NaN
#
#    closed_date taxi_pick_up_location bridge_highway_name  \
# 1          NaN                   NaN                 NaN
# 4          NaN                   NaN                 NaN
# 7          NaN                   NaN                 NaN
# 12         NaN                   NaN                 NaN
# 13         NaN                   NaN                 NaN
#
#    bridge_highway_direction road_ramp bridge_highway_segment facility_type
# 1                       NaN       NaN                    NaN           NaN
# 4                       NaN       NaN                    NaN           NaN
# 7                       NaN       NaN                    NaN           NaN
# 12                      NaN       NaN                    NaN           NaN
# 13                      NaN       NaN                    NaN           NaN
#
# [5 rows x 45 columns]

# %%
## we are interested in the number of noise complaints in each neighborhood. Which neighborhood has the most noise complaints?

noise_311.groupby(['park_borough']).count()[['complaint_type']]
# Out:
#                complaint_type
# park_borough
# BRONX                     199
# BROOKLYN                  188
# MANHATTAN                 126
# QUEENS                    144
# STATEN ISLAND              12
